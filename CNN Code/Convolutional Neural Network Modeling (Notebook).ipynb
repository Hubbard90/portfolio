# %% [markdown]
# # Importing Data

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import (Dense, Dropout, Flatten,
                                     Conv2D, MaxPooling2D)
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
#reshape dataset to have a single channel
x_train = x_train.reshape((x_train.shape[0],28,28,1))
x_test = x_test.reshape((x_test.shape[0],28,28,1))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(x_train[i].reshape(28, 28), cmap='gray')
    plt.axis('off')
plt.show()

# %% [markdown]
# # Preprocessing

# %%
# One-hot encoding for multi-class classification (ONLY ONE CLASS PER ITEM!!!!)
# Activation function for output: Softmax

# scale
x_train = x_train / 255.0
x_test  = x_test / 255.0

# one-hot coding
num_classes = 10
y_train_oh = to_categorical(y_train, num_classes)
y_test_oh  = to_categorical(y_test, num_classes)

# %%
# Callbacks:
early_stop = EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True) # This callback monitors the validation accuracy (val_accuracy) during training. If the validation accuracy doesn't improve for 5 consecutive epochs (patience=5), training will stop early. restore_best_weights=True ensures that the model weights from the epoch with the best validation accuracy are restored.
reduce_lr  = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3) # this callback monitors the validation loss (val_loss). If the validation loss doesn't decrease for 3 consecutive epochs (patience=3), the learning rate of the optimizer will be reduced by a factor of 0.5 (factor=0.5). This helps the model to converge when the loss has plateaued.

# %% [markdown]
# # Task 1

# %%
# prevents overfitting by slightly modifying images
datagen = ImageDataGenerator(rotation_range=10,
                             width_shift_range=0.1,
                             height_shift_range=0.1)
datagen.fit(x_train)

# %%
# Baseline NN model
mlp = Sequential([
    Flatten(input_shape=(28, 28, 1)),
    Dense(128, activation="relu"),
    Dropout(0.2),
    Dense(num_classes, activation="softmax")
])

mlp.compile(optimizer=Adam(learning_rate=1e-3),
            loss="categorical_crossentropy",
            metrics=["accuracy"])

history_mlp = mlp.fit(
    x_train, y_train_oh,
    validation_split=0.1,
    epochs=30, batch_size=128,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

mlp_test_loss, mlp_test_acc = mlp.evaluate(x_test, y_test_oh, verbose=0)
print(f"MLP Test Accuracy: {mlp_test_acc:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7155 - loss: 0.8299 - val_accuracy: 0.8468 - val_loss: 0.4310 - learning_rate: 0.0010
# Epoch 2/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8463 - loss: 0.4448 - val_accuracy: 0.8587 - val_loss: 0.3903 - learning_rate: 0.0010
# Epoch 3/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8600 - loss: 0.3959 - val_accuracy: 0.8660 - val_loss: 0.3644 - learning_rate: 0.0010
# Epoch 4/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8686 - loss: 0.3651 - val_accuracy: 0.8760 - val_loss: 0.3593 - learning_rate: 0.0010
# Epoch 5/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8760 - loss: 0.3446 - val_accuracy: 0.8793 - val_loss: 0.3335 - learning_rate: 0.0010
# Epoch 6/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8804 - loss: 0.3310 - val_accuracy: 0.8780 - val_loss: 0.3423 - learning_rate: 0.0010
# Epoch 7/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8826 - loss: 0.3210 - val_accuracy: 0.8798 - val_loss: 0.3429 - learning_rate: 0.0010
# Epoch 8/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8888 - loss: 0.3062 - val_accuracy: 0.8833 - val_loss: 0.3246 - learning_rate: 0.0010
# Epoch 9/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8935 - loss: 0.2917 - val_accuracy: 0.8843 - val_loss: 0.3262 - learning_rate: 0.0010
# Epoch 10/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8930 - loss: 0.2903 - val_accuracy: 0.8785 - val_loss: 0.3350 - learning_rate: 0.0010
# Epoch 11/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8958 - loss: 0.2826 - val_accuracy: 0.8815 - val_loss: 0.3237 - learning_rate: 0.0010
# Epoch 12/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8954 - loss: 0.2801 - val_accuracy: 0.8842 - val_loss: 0.3268 - learning_rate: 0.0010
# Epoch 13/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8996 - loss: 0.2726 - val_accuracy: 0.8803 - val_loss: 0.3224 - learning_rate: 0.0010
# Epoch 14/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9004 - loss: 0.2674 - val_accuracy: 0.8885 - val_loss: 0.3056 - learning_rate: 0.0010
# Epoch 15/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9054 - loss: 0.2538 - val_accuracy: 0.8882 - val_loss: 0.3110 - learning_rate: 0.0010
# Epoch 16/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9068 - loss: 0.2507 - val_accuracy: 0.8823 - val_loss: 0.3258 - learning_rate: 0.0010
# Epoch 17/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9092 - loss: 0.2452 - val_accuracy: 0.8883 - val_loss: 0.3084 - learning_rate: 0.0010
# Epoch 18/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9143 - loss: 0.2329 - val_accuracy: 0.8930 - val_loss: 0.3060 - learning_rate: 5.0000e-04
# Epoch 19/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9161 - loss: 0.2226 - val_accuracy: 0.8925 - val_loss: 0.2981 - learning_rate: 5.0000e-04
# Epoch 20/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9188 - loss: 0.2228 - val_accuracy: 0.8908 - val_loss: 0.3022 - learning_rate: 5.0000e-04
# Epoch 21/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9195 - loss: 0.2207 - val_accuracy: 0.8935 - val_loss: 0.2999 - learning_rate: 5.0000e-04
# Epoch 22/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9177 - loss: 0.2156 - val_accuracy: 0.8977 - val_loss: 0.2949 - learning_rate: 5.0000e-04
# Epoch 23/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9236 - loss: 0.2095 - val_accuracy: 0.8942 - val_loss: 0.3105 - learning_rate: 5.0000e-04
# Epoch 24/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9220 - loss: 0.2124 - val_accuracy: 0.8948 - val_loss: 0.2985 - learning_rate: 5.0000e-04
# Epoch 25/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9235 - loss: 0.2091 - val_accuracy: 0.8958 - val_loss: 0.2994 - learning_rate: 5.0000e-04
# Epoch 26/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9234 - loss: 0.2051 - val_accuracy: 0.8942 - val_loss: 0.3005 - learning_rate: 2.5000e-04
# Epoch 27/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9256 - loss: 0.1994 - val_accuracy: 0.8962 - val_loss: 0.2989 - learning_rate: 2.5000e-04
# MLP Test Accuracy: 0.8909

# %%
# Baseline NN model Improvmnet
mlp2 = Sequential([
    Flatten(input_shape=(28, 28, 1)),
    Dense(512, activation="relu"),
    Dropout(0.3),
    Dense(256, activation="relu"),
    Dropout(0.3),
    Dense(128, activation="relu"),
    Dropout(0.3),
    Dense(num_classes, activation="softmax")
])

mlp2.compile(optimizer=Adam(1e-3), loss="categorical_crossentropy", metrics=["accuracy"])
mlp2.fit(x_train, y_train_oh, validation_split=0.1, epochs=30, batch_size=128,
         callbacks=[early_stop, reduce_lr], verbose=1)
print("MLP2 Test Acc:", mlp2.evaluate(x_test, y_test_oh, verbose=0)[1])
# Out:
# Epoch 1/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.6737 - loss: 0.9084 - val_accuracy: 0.8453 - val_loss: 0.4216 - learning_rate: 0.0010
# Epoch 2/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8377 - loss: 0.4550 - val_accuracy: 0.8613 - val_loss: 0.3797 - learning_rate: 0.0010
# Epoch 3/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8539 - loss: 0.4022 - val_accuracy: 0.8685 - val_loss: 0.3602 - learning_rate: 0.0010
# Epoch 4/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8653 - loss: 0.3755 - val_accuracy: 0.8667 - val_loss: 0.3538 - learning_rate: 0.0010
# Epoch 5/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8695 - loss: 0.3605 - val_accuracy: 0.8660 - val_loss: 0.3512 - learning_rate: 0.0010
# Epoch 6/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8710 - loss: 0.3534 - val_accuracy: 0.8735 - val_loss: 0.3317 - learning_rate: 0.0010
# Epoch 7/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8783 - loss: 0.3330 - val_accuracy: 0.8692 - val_loss: 0.3538 - learning_rate: 0.0010
# Epoch 8/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8777 - loss: 0.3270 - val_accuracy: 0.8762 - val_loss: 0.3294 - learning_rate: 0.0010
# Epoch 9/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8831 - loss: 0.3151 - val_accuracy: 0.8830 - val_loss: 0.3155 - learning_rate: 0.0010
# Epoch 10/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8885 - loss: 0.3061 - val_accuracy: 0.8827 - val_loss: 0.3143 - learning_rate: 0.0010
# Epoch 11/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8932 - loss: 0.2954 - val_accuracy: 0.8877 - val_loss: 0.3159 - learning_rate: 0.0010
# Epoch 12/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8925 - loss: 0.2926 - val_accuracy: 0.8868 - val_loss: 0.3087 - learning_rate: 0.0010
# Epoch 13/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8930 - loss: 0.2887 - val_accuracy: 0.8890 - val_loss: 0.3095 - learning_rate: 0.0010
# Epoch 14/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8961 - loss: 0.2821 - val_accuracy: 0.8835 - val_loss: 0.3165 - learning_rate: 0.0010
# Epoch 15/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8978 - loss: 0.2796 - val_accuracy: 0.8870 - val_loss: 0.3204 - learning_rate: 0.0010
# Epoch 16/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9064 - loss: 0.2572 - val_accuracy: 0.8877 - val_loss: 0.3111 - learning_rate: 5.0000e-04
# Epoch 17/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9070 - loss: 0.2488 - val_accuracy: 0.8930 - val_loss: 0.2980 - learning_rate: 5.0000e-04
# Epoch 18/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9111 - loss: 0.2360 - val_accuracy: 0.8917 - val_loss: 0.3044 - learning_rate: 5.0000e-04
# Epoch 19/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9118 - loss: 0.2353 - val_accuracy: 0.8913 - val_loss: 0.2969 - learning_rate: 5.0000e-04
# Epoch 20/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9129 - loss: 0.2293 - val_accuracy: 0.8935 - val_loss: 0.3027 - learning_rate: 5.0000e-04
# Epoch 21/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9120 - loss: 0.2319 - val_accuracy: 0.8925 - val_loss: 0.2993 - learning_rate: 5.0000e-04
# Epoch 22/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9178 - loss: 0.2183 - val_accuracy: 0.8923 - val_loss: 0.2975 - learning_rate: 5.0000e-04
# Epoch 23/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9193 - loss: 0.2107 - val_accuracy: 0.8957 - val_loss: 0.3033 - learning_rate: 2.5000e-04
# Epoch 24/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9229 - loss: 0.2039 - val_accuracy: 0.8973 - val_loss: 0.3035 - learning_rate: 2.5000e-04
# Epoch 25/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9283 - loss: 0.1942 - val_accuracy: 0.8993 - val_loss: 0.2973 - learning_rate: 2.5000e-04
# Epoch 26/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9287 - loss: 0.1902 - val_accuracy: 0.8985 - val_loss: 0.2987 - learning_rate: 1.2500e-04
# Epoch 27/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9280 - loss: 0.1887 - val_accuracy: 0.9000 - val_loss: 0.2975 - learning_rate: 1.2500e-04
# Epoch 28/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9299 - loss: 0.1842 - val_accuracy: 0.8990 - val_loss: 0.3038 - learning_rate: 1.2500e-04
# Epoch 29/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9306 - loss: 0.1796 - val_accuracy: 0.8998 - val_loss: 0.3044 - learning_rate: 6.2500e-05
# Epoch 30/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9307 - loss: 0.1812 - val_accuracy: 0.8998 - val_loss: 0.3042 - learning_rate: 6.2500e-05
# MLP2 Test Acc: 0.8992999792098999

# %%
history_mlp2 = mlp2.fit(
    x_train, y_train_oh,
    validation_split=0.1,
    epochs=30,
    batch_size=128,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

import matplotlib.pyplot as plt

# Accuracy plot
plt.figure(figsize=(8,5))
plt.plot(history_mlp2.history['accuracy'], label='Training Accuracy')
plt.plot(history_mlp2.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Loss plot
plt.figure(figsize=(8,5))
plt.plot(history_mlp2.history['loss'], label='Training Loss')
plt.plot(history_mlp2.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9280 - loss: 0.1860 - val_accuracy: 0.8987 - val_loss: 0.3035 - learning_rate: 6.2500e-05
# Epoch 2/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9331 - loss: 0.1805 - val_accuracy: 0.8978 - val_loss: 0.3050 - learning_rate: 6.2500e-05
# Epoch 3/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9313 - loss: 0.1811 - val_accuracy: 0.8988 - val_loss: 0.3033 - learning_rate: 6.2500e-05
# Epoch 4/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9308 - loss: 0.1797 - val_accuracy: 0.8992 - val_loss: 0.3073 - learning_rate: 6.2500e-05
# Epoch 5/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9318 - loss: 0.1816 - val_accuracy: 0.8995 - val_loss: 0.3017 - learning_rate: 6.2500e-05
# Epoch 6/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9297 - loss: 0.1815 - val_accuracy: 0.8998 - val_loss: 0.3053 - learning_rate: 6.2500e-05
# Epoch 7/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9306 - loss: 0.1800 - val_accuracy: 0.8997 - val_loss: 0.3051 - learning_rate: 6.2500e-05
# Epoch 8/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9335 - loss: 0.1756 - val_accuracy: 0.9002 - val_loss: 0.3064 - learning_rate: 6.2500e-05
# Epoch 9/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9346 - loss: 0.1734 - val_accuracy: 0.9013 - val_loss: 0.3093 - learning_rate: 3.1250e-05
# Epoch 10/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9338 - loss: 0.1723 - val_accuracy: 0.8980 - val_loss: 0.3097 - learning_rate: 3.1250e-05
# Epoch 11/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9332 - loss: 0.1768 - val_accuracy: 0.9003 - val_loss: 0.3077 - learning_rate: 3.1250e-05
# Epoch 12/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9348 - loss: 0.1715 - val_accuracy: 0.9013 - val_loss: 0.3080 - learning_rate: 1.5625e-05
# Epoch 13/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9349 - loss: 0.1726 - val_accuracy: 0.9007 - val_loss: 0.3094 - learning_rate: 1.5625e-05
# Epoch 14/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9306 - loss: 0.1752 - val_accuracy: 0.9007 - val_loss: 0.3100 - learning_rate: 1.5625e-05

# %% [markdown]
# # Task 2

# %%
cnn = Sequential([
    Conv2D(32, (3,3), activation="relu", padding="same", input_shape=(28,28,1)),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation="relu", padding="same"),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])

cnn.compile(optimizer=Adam(1e-3),
            loss="categorical_crossentropy",
            metrics=["accuracy"])


use_aug = True
if use_aug:
    history_cnn = cnn.fit(datagen.flow(x_train, y_train_oh, batch_size=128),
                          validation_data=(x_test, y_test_oh),
                          epochs=30,
                          callbacks=[early_stop, reduce_lr], verbose=1)
else:
    history_cnn = cnn.fit(x_train, y_train_oh, validation_split=0.1,
                          epochs=30, batch_size=128,
                          callbacks=[early_stop, reduce_lr], verbose=1)

cnn_test_loss, cnn_test_acc = cnn.evaluate(x_test, y_test_oh, verbose=0)
print(f"CNN Test Accuracy: {cnn_test_acc:.4f}")
# Out:
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 47ms/step - accuracy: 0.6268 - loss: 1.0207 - val_accuracy: 0.8118 - val_loss: 0.4830 - learning_rate: 0.0010
# Epoch 2/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.7861 - loss: 0.5768 - val_accuracy: 0.8487 - val_loss: 0.4141 - learning_rate: 0.0010
# Epoch 3/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8041 - loss: 0.5198 - val_accuracy: 0.8508 - val_loss: 0.3948 - learning_rate: 0.0010
# Epoch 4/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.8208 - loss: 0.4808 - val_accuracy: 0.8666 - val_loss: 0.3509 - learning_rate: 0.0010
# Epoch 5/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.8370 - loss: 0.4442 - val_accuracy: 0.8768 - val_loss: 0.3336 - learning_rate: 0.0010
# Epoch 6/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8433 - loss: 0.4258 - val_accuracy: 0.8750 - val_loss: 0.3340 - learning_rate: 0.0010
# Epoch 7/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.8516 - loss: 0.4044 - val_accuracy: 0.8898 - val_loss: 0.3035 - learning_rate: 0.0010
# Epoch 8/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8559 - loss: 0.3900 - val_accuracy: 0.8897 - val_loss: 0.2929 - learning_rate: 0.0010
# Epoch 9/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.8664 - loss: 0.3718 - val_accuracy: 0.8925 - val_loss: 0.2857 - learning_rate: 0.0010
# Epoch 10/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8679 - loss: 0.3572 - val_accuracy: 0.8928 - val_loss: 0.2825 - learning_rate: 0.0010
# Epoch 11/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.8686 - loss: 0.3631 - val_accuracy: 0.8935 - val_loss: 0.2856 - learning_rate: 0.0010
# Epoch 12/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.8719 - loss: 0.3517 - val_accuracy: 0.8952 - val_loss: 0.2763 - learning_rate: 0.0010
# Epoch 13/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8794 - loss: 0.3330 - val_accuracy: 0.8928 - val_loss: 0.2751 - learning_rate: 0.0010
# Epoch 14/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.8793 - loss: 0.3300 - val_accuracy: 0.9022 - val_loss: 0.2672 - learning_rate: 0.0010
# Epoch 15/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8831 - loss: 0.3227 - val_accuracy: 0.9013 - val_loss: 0.2621 - learning_rate: 0.0010
# Epoch 16/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.8812 - loss: 0.3266 - val_accuracy: 0.9026 - val_loss: 0.2666 - learning_rate: 0.0010
# Epoch 17/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 19s 40ms/step - accuracy: 0.8821 - loss: 0.3192 - val_accuracy: 0.9011 - val_loss: 0.2661 - learning_rate: 0.0010
# Epoch 18/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.8860 - loss: 0.3145 - val_accuracy: 0.9046 - val_loss: 0.2556 - learning_rate: 0.0010
# Epoch 19/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.8875 - loss: 0.3051 - val_accuracy: 0.9068 - val_loss: 0.2513 - learning_rate: 0.0010
# Epoch 20/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.8872 - loss: 0.3039 - val_accuracy: 0.9059 - val_loss: 0.2559 - learning_rate: 0.0010
# Epoch 21/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.8940 - loss: 0.2903 - val_accuracy: 0.9115 - val_loss: 0.2415 - learning_rate: 0.0010
# Epoch 22/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8894 - loss: 0.3048 - val_accuracy: 0.9069 - val_loss: 0.2491 - learning_rate: 0.0010
# Epoch 23/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.8907 - loss: 0.2955 - val_accuracy: 0.9084 - val_loss: 0.2536 - learning_rate: 0.0010
# Epoch 24/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.8922 - loss: 0.2969 - val_accuracy: 0.9136 - val_loss: 0.2394 - learning_rate: 0.0010
# Epoch 25/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.8912 - loss: 0.2922 - val_accuracy: 0.9142 - val_loss: 0.2387 - learning_rate: 0.0010
# Epoch 26/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.8928 - loss: 0.2920 - val_accuracy: 0.9074 - val_loss: 0.2416 - learning_rate: 0.0010
# Epoch 27/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8951 - loss: 0.2823 - val_accuracy: 0.9117 - val_loss: 0.2378 - learning_rate: 0.0010
# Epoch 28/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.8954 - loss: 0.2815 - val_accuracy: 0.9097 - val_loss: 0.2440 - learning_rate: 0.0010
# Epoch 29/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.8960 - loss: 0.2790 - val_accuracy: 0.9144 - val_loss: 0.2325 - learning_rate: 0.0010
# Epoch 30/30
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.8956 - loss: 0.2817 - val_accuracy: 0.9134 - val_loss: 0.2372 - learning_rate: 0.0010
# CNN Test Accuracy: 0.9144

# %%
# Model improvement
cnn2 = Sequential([
    Conv2D(32, (3,3), activation="relu", padding="same", input_shape=(28,28,1)),
    Conv2D(32, (3,3), activation="relu", padding="same"),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation="relu", padding="same"),
    Conv2D(64, (3,3), activation="relu", padding="same"),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(256, activation="relu"),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])

cnn2.compile(optimizer=Adam(1e-3),
             loss="categorical_crossentropy",
             metrics=["accuracy"])

cnn2.fit(x_train, y_train_oh, validation_split=0.1, epochs=30, batch_size=128,
         callbacks=[early_stop, reduce_lr], verbose=1)
print("CNN2 Test Acc:", cnn2.evaluate(x_test, y_test_oh, verbose=0)[1])
# Out:
# Epoch 1/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7206 - loss: 0.7702 - val_accuracy: 0.8763 - val_loss: 0.3279 - learning_rate: 0.0010
# Epoch 2/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8816 - loss: 0.3284 - val_accuracy: 0.9053 - val_loss: 0.2512 - learning_rate: 0.0010
# Epoch 3/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9022 - loss: 0.2700 - val_accuracy: 0.9183 - val_loss: 0.2225 - learning_rate: 0.0010
# Epoch 4/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9186 - loss: 0.2272 - val_accuracy: 0.9153 - val_loss: 0.2199 - learning_rate: 0.0010
# Epoch 5/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9253 - loss: 0.2054 - val_accuracy: 0.9248 - val_loss: 0.2075 - learning_rate: 0.0010
# Epoch 6/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9346 - loss: 0.1786 - val_accuracy: 0.9255 - val_loss: 0.2010 - learning_rate: 0.0010
# Epoch 7/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9412 - loss: 0.1606 - val_accuracy: 0.9287 - val_loss: 0.1908 - learning_rate: 0.0010
# Epoch 8/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9463 - loss: 0.1422 - val_accuracy: 0.9257 - val_loss: 0.2031 - learning_rate: 0.0010
# Epoch 9/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9521 - loss: 0.1279 - val_accuracy: 0.9292 - val_loss: 0.1934 - learning_rate: 0.0010
# Epoch 10/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9576 - loss: 0.1135 - val_accuracy: 0.9302 - val_loss: 0.2072 - learning_rate: 0.0010
# Epoch 11/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9658 - loss: 0.0896 - val_accuracy: 0.9308 - val_loss: 0.2222 - learning_rate: 5.0000e-04
# Epoch 12/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9735 - loss: 0.0713 - val_accuracy: 0.9328 - val_loss: 0.2220 - learning_rate: 5.0000e-04
# Epoch 13/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9765 - loss: 0.0625 - val_accuracy: 0.9323 - val_loss: 0.2341 - learning_rate: 5.0000e-04
# Epoch 14/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9814 - loss: 0.0510 - val_accuracy: 0.9352 - val_loss: 0.2447 - learning_rate: 2.5000e-04
# Epoch 15/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9858 - loss: 0.0398 - val_accuracy: 0.9355 - val_loss: 0.2505 - learning_rate: 2.5000e-04
# Epoch 16/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9865 - loss: 0.0362 - val_accuracy: 0.9348 - val_loss: 0.2593 - learning_rate: 2.5000e-04
# Epoch 17/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9882 - loss: 0.0327 - val_accuracy: 0.9357 - val_loss: 0.2743 - learning_rate: 1.2500e-04
# Epoch 18/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9900 - loss: 0.0275 - val_accuracy: 0.9360 - val_loss: 0.2850 - learning_rate: 1.2500e-04
# Epoch 19/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9912 - loss: 0.0255 - val_accuracy: 0.9345 - val_loss: 0.2907 - learning_rate: 1.2500e-04
# Epoch 20/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9914 - loss: 0.0238 - val_accuracy: 0.9358 - val_loss: 0.2936 - learning_rate: 6.2500e-05
# Epoch 21/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9922 - loss: 0.0218 - val_accuracy: 0.9360 - val_loss: 0.2974 - learning_rate: 6.2500e-05
# Epoch 22/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9930 - loss: 0.0205 - val_accuracy: 0.9358 - val_loss: 0.3028 - learning_rate: 6.2500e-05
# Epoch 23/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9929 - loss: 0.0204 - val_accuracy: 0.9362 - val_loss: 0.3090 - learning_rate: 3.1250e-05
# Epoch 24/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9931 - loss: 0.0189 - val_accuracy: 0.9355 - val_loss: 0.3096 - learning_rate: 3.1250e-05
# Epoch 25/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9942 - loss: 0.0177 - val_accuracy: 0.9345 - val_loss: 0.3132 - learning_rate: 3.1250e-05
# Epoch 26/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9948 - loss: 0.0169 - val_accuracy: 0.9357 - val_loss: 0.3154 - learning_rate: 1.5625e-05
# Epoch 27/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9937 - loss: 0.0181 - val_accuracy: 0.9353 - val_loss: 0.3225 - learning_rate: 1.5625e-05
# Epoch 28/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9939 - loss: 0.0180 - val_accuracy: 0.9352 - val_loss: 0.3196 - learning_rate: 1.5625e-05
# CNN2 Test Acc: 0.9369000196456909

# %%
history_cnn2 = cnn2.fit(
    x_train, y_train_oh,
    validation_split=0.1,
    epochs=30,
    batch_size=128,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)


import numpy as np
import matplotlib.pyplot as plt

acc = history_cnn2.history['accuracy']
val_acc = history_cnn2.history['val_accuracy']
loss = history_cnn2.history['loss']
val_loss = history_cnn2.history['val_loss']
epochs = range(1, len(acc) + 1)

best_val_loss_epoch = int(np.argmin(val_loss)) + 1

# Accuracy
plt.figure(figsize=(8,5))
plt.plot(epochs, acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.axvline(best_val_loss_epoch, linestyle='--', alpha=0.6,
            label=f'Best Val Loss @ epoch {best_val_loss_epoch}')
plt.title('CNN2: Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Loss
plt.figure(figsize=(8,5))
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.axvline(best_val_loss_epoch, linestyle='--', alpha=0.6,
            label=f'Best Val Loss @ epoch {best_val_loss_epoch}')
plt.title('CNN2: Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Optional: quick numeric check of generalization gap at the end
final_gap = float(acc[-1] - val_acc[-1])
print(f"Final generalization gap (acc - val_acc): {final_gap:.4f}")
# Out:
# Epoch 1/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9926 - loss: 0.0190 - val_accuracy: 0.9365 - val_loss: 0.3091 - learning_rate: 7.8125e-06
# Epoch 2/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9937 - loss: 0.0171 - val_accuracy: 0.9353 - val_loss: 0.3092 - learning_rate: 7.8125e-06
# Epoch 3/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9931 - loss: 0.0193 - val_accuracy: 0.9357 - val_loss: 0.3110 - learning_rate: 7.8125e-06
# Epoch 4/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9942 - loss: 0.0176 - val_accuracy: 0.9358 - val_loss: 0.3120 - learning_rate: 7.8125e-06
# Epoch 5/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9940 - loss: 0.0175 - val_accuracy: 0.9357 - val_loss: 0.3120 - learning_rate: 3.9063e-06
# Epoch 6/30
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9928 - loss: 0.0197 - val_accuracy: 0.9355 - val_loss: 0.3137 - learning_rate: 3.9063e-06
# Final generalization gap (acc - val_acc): 0.0582

# %% [markdown]
# # Task 3

# %%
from tensorflow.keras.optimizers import RMSprop

def train_with_optimizer(model_fn, optimizer, lr):
    model = model_fn()
    model.compile(optimizer=optimizer(learning_rate=lr),
                  loss="categorical_crossentropy",
                  metrics=["accuracy"])
    model.fit(x_train, y_train_oh, validation_split=0.1, epochs=20, batch_size=128,
              callbacks=[early_stop, reduce_lr], verbose=0)
    return model.evaluate(x_test, y_test_oh, verbose=0)[1]


def cnn_factory():
    m = Sequential([
    Conv2D(32, (3,3), activation="relu", padding="same", input_shape=(28,28,1)),
    Conv2D(32, (3,3), activation="relu", padding="same"),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation="relu", padding="same"),
    Conv2D(64, (3,3), activation="relu", padding="same"),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(256, activation="relu"),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])
    return m


results = {}
results["Adam 0.0001"] = train_with_optimizer(cnn_factory, Adam, 0.0001)
results["Adam 0.00003"] = train_with_optimizer(cnn_factory, Adam, 0.00003)
results["Adam 0.00005"] = train_with_optimizer(cnn_factory, Adam, 0.00005)
results["SGD 0.01"]  = train_with_optimizer(cnn_factory, SGD, 0.01)
results["SGD 0.03"]  = train_with_optimizer(cnn_factory, SGD, 0.03)
results["SGD 0.05"]  = train_with_optimizer(cnn_factory, SGD, 0.05)
results["RMSProp 0.01"]  = train_with_optimizer(cnn_factory, RMSprop, 0.001)
results["RMSProp 0.03"]  = train_with_optimizer(cnn_factory, RMSprop, 0.0003)
results["RMSProp 0.05"]  = train_with_optimizer(cnn_factory, RMSprop, 0.0005)

for key, value in results.items():
    print(f"{key}: {value}\n")

# %%
def train_with_optimizer(model_fn, optimizer, lr):
    model = model_fn()
    model.compile(optimizer=optimizer(learning_rate=lr),
                  loss="categorical_crossentropy",
                  metrics=["accuracy"])
    model.fit(x_train, y_train_oh, validation_split=0.1, epochs=20, batch_size=128,
              callbacks=[early_stop, reduce_lr], verbose=0)
    return model.evaluate(x_test, y_test_oh, verbose=0)[1]


def cnn_factory():
    m = Sequential([
        Conv2D(32, (3,3), activation="relu", padding="same", input_shape=(28,28,1)),
        Conv2D(32, (3,3), activation="relu", padding="same"),
        MaxPooling2D((2,2)),
        Conv2D(64, (3,3), activation="relu", padding="same"),
        Conv2D(64, (3,3), activation="relu", padding="same"),
        MaxPooling2D((2,2)),
        Flatten(),
        Dense(256, activation="relu"),
        Dropout(0.5),
        Dense(num_classes, activation="softmax")
    ])
    return m

def train_with_optimizer_callbacks(model_fn, optimizer):
    model = model_fn()
    model.compile(optimizer=optimizer(learning_rate=0.001),
                  loss="categorical_crossentropy",
                  metrics=["accuracy"])

    model.fit(
        x_train, y_train_oh,
        validation_split=0.1,
        epochs=30,
        batch_size=128,
        callbacks=[early_stop, reduce_lr],
        verbose=1
    )

    test_loss, test_acc = model.evaluate(x_test, y_test_oh, verbose=0)
    return test_acc

optimizers = [Adam, SGD, RMSprop]
results = {}

for opt in optimizers:
    name = opt.__name__
    print(f"\nTraining with {name}...")
    results[name] = train_with_optimizer_callbacks(cnn_factory, opt)

for key, value in results.items():
    print(f"{key}: {value:.4f}")

best_opt = max(results, key=results.get)
print(f"\n✅ Best optimizer: {best_opt} with accuracy {results[best_opt]:.4f}")
